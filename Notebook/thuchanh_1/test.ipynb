# %%
import numpy as np
import pandas as pd

# %%
emps = pd.read_excel('employees.xls')

# %%
emps.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
emps
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
deps = pd.read_excel('departments.xls')

# %%
deps
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
emps.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
emps.shape
# Out:
# (107, 11)

# %%
deps.shape
# Out:
# (27, 4)

# %%
# tao mot dataframe df gom hai cot department_id, department_name
df = deps[['DEPARTMENT_ID','DEPARTMENT_NAME']]

# %%
df
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
# ket hop emps voi df theo cot edepatrment_id
df_ = pd.merge(emps, df,on='DEPARTMENT_ID')

# %%
df_
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
emps.shape
# Out:
# (107, 11)

# %%
df_.shape
# Out:
# (106, 12)

# %%
emps[emps['DEPARTMENT_ID'].isna()]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL        PHONE_NUMBER  \
# 78          178  Kimberely     Grant  KGRANT  011.44.1644.429263
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 78            NaN

# %%
df_ = pd.merge(emps, df,on='DEPARTMENT_ID', how='left')

# %%
df_.shape
# Out:
# (107, 12)

# %%
# tinh tong luong cua cac phong
df_sum_salary = df_.groupby('DEPARTMENT_NAME').SALARY.sum()

# %%
print(type(df_sum_salary))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_sum_salary.index
# Out:
# Index(['Accounting', 'Administration', 'Executive', 'Finance',
#        'Human Resources', 'IT', 'Marketing', 'Public Relations', 'Purchasing',
#        'Sales', 'Shipping'],
#       dtype='object', name='DEPARTMENT_NAME')

# %%
df_sum_salary = df_.groupby('DEPARTMENT_NAME', as_index=False).SALARY.sum()

# %%
df_sum_salary
# Out:
#      DEPARTMENT_NAME  SALARY
# 0         Accounting   20308
# 1     Administration    4400
# 2          Executive   58000
# 3            Finance   51608
# 4    Human Resources    6500
# 5                 IT   28800
# 6          Marketing   19000
# 7   Public Relations   10000
# 8         Purchasing   24900
# 9              Sales  304500
# 10          Shipping  156400

# %%
df_sum_salary = df_.groupby('DEPARTMENT_NAME').SALARY.sum()

# %%
df_sum_salary.plot.bar()

# %%
# aggregate: cac ham ve nhom sum, mean, count, min, max
data = df_.groupby('DEPARTMENT_NAME').SALARY.agg(['sum','count'])

# %%
data
# Out:
#                      sum  count
# DEPARTMENT_NAME
# Accounting         20308      2
# Administration      4400      1
# Executive          58000      3
# Finance            51608      6
# Human Resources     6500      1
# IT                 28800      5
# Marketing          19000      2
# Public Relations   10000      1
# Purchasing         24900      6
# Sales             304500     34
# Shipping          156400     45

# %%
data['count'] = data['count']*1000

# %%
data.plot.bar()

# %%
df_['nam_vao_lam'] = pd.DatetimeIndex(df_['HIRE_DATE']).year

# %%
# df_[['HIRE_DATE','nam_vao_lam']]
df_count = df_.groupby('nam_vao_lam').EMPLOYEE_ID.count()

# %%
df_count
# Out:
# nam_vao_lam
# 2001     1
# 2002     7
# 2003     6
# 2004    10
# 2005    29
# 2006    24
# 2007    19
# 2008    11
# Name: EMPLOYEE_ID, dtype: int64

# %%
df_count.plot.bar()
