# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# doc iris, titanic, tips
iris = sb.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
tips = sb.load_dataset('tips')

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
titanic = sb.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.distplot(tips['total_bill'])

# %%
sb.distplot(tips['tip'])

# %%
sb.regplot(data=iris, x='petal_length',y='petal_width')

# %%
sb.lmplot(data=iris, x='petal_length',y='petal_width')

# %%
sb.lmplot(data=iris, x='petal_length',y='petal_width', hue='species')

# %%
sb.lmplot(data=iris, x='petal_length',y='petal_width', col='species')

# %%
# tips. x=total_bill. y=tip
sb.lmplot(data=tips, x='total_bill',y='tip')

# %%
sb.lmplot(data=tips, x='total_bill',y='tip', hue='sex')

# %%
sb.boxplot(data=titanic, x='class',y='survived')

# %%
sb.barplot(data=titanic, x='class',y='survived')

# %%
sb.barplot(data=titanic, x='class',y='survived', ci=False, hue='sex') # confidence interval

# %%
# biet so luong dan ong + dan ba trong cac khoang
sb.countplot(data=titanic, x='sex', hue='class')

# %%
sb.countplot(data=titanic,y='class', hue='survived')

# %%
# so hanh khach trong moi khoang
sb.countplot(data=titanic,y='class', hue='survived')

# %%
my_data=titanic[titanic['survived']==1]
# so hanh khach duoc cuu song trong moi khoang
sb.countplot(data=my_data,y='class')

# %%
my_data.groupby('class').count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        136     136  136  122    136    136   136       134  136
# Second        87      87   87   83     87     87    87        87   87
# Third        119     119  119   85    119    119   119       119  119
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          136   117          134    136    136
# Second          87    13           87     87     87
# Third          119     6          119    119    119
