# %%
import numpy as np
import pandas as pd

# %%
ages = [18,19,21,20,17]
arr = np.array(ages)
arr
# Out:
# array([18, 19, 21, 20, 17])

# %%
ser = pd.Series(arr)
ser
# Out:
# 0    18
# 1    19
# 2    21
# 3    20
# 4    17
# dtype: int32

# %%
ser = pd.Series({'AGE': arr})

# %%
ser
# Out:
# AGE    [18, 19, 21, 20, 17]
# dtype: object

# %%
ser_1 = ser.map(lambda x: x+2)

# %%
ser_1
# Out:
# AGE    [20, 21, 23, 22, 19]
# dtype: object

# %%
ser = pd.Series({'NAME':['Tu','Mai','Ngoc','Minh']})

# %%
ser_2 = ser.map(lambda x: str(x).upper())

# %%
ser.values
# Out:
# array([list(['Tu', 'Mai', 'Ngoc', 'Minh'])], dtype=object)

# %%
# tu hai tap tin weights_1.txt va heights_1.txt, hay tao hai DataFrame voi hai cot la height va weight

# %%
l_height = [74, 74, 72, 72, 73, 69, 69, 71, 76, 71, 73, 73, 74, 74, 69, 70, 73, 75, 78, 79, 76, 74, 76, 72, 71, 75, 77, 74, 73, 74, 78, 73, 75, 73, 75, 75, 74, 69, 71, 74, 73, 73, 76, 74, 74, 70, 72, 77, 74, 70, 73, 75, 76, 76, 78, 74, 74, 76, 77, 81, 78, 75, 77, 75, 76, 74, 72, 72, 75, 73,  73, 73, 70, 70, 70, 76, 68, 71, 72, 75, 75, 75, 75, 68, 74, 78, 71, 73, 76, 74, 74, 79, 75, 73, 76, 74, 74, 73, 72, 74, 73, 74, 72, 73, 69, 72, 73, 75, 75, 73, 72, 72, 76, 74, 72, 77, 74, 77, 75, 76, 80, 74, 74, 75, 78, 73, 73, 74, 75, 76, 71, 73, 74, 76, 76, 74, 73, 74, 70, 72,  73, 73, 73, 73, 71, 74, 74, 72, 74, 71, 74, 73, 75, 75, 79, 73, 75, 76, 74, 76, 78, 74, 76, 72, 74, 76, 74, 75, 78, 75, 72, 74, 72, 74, 70, 71, 70, 75, 71, 71, 73, 72, 71, 73, 72, 75, 74, 74, 75, 73, 77, 73, 76, 75, 74, 76, 75, 73, 71, 76, 75, 72, 71, 77, 73, 74, 71, 72, 74, 75,    73, 72, 75, 75, 74, 72, 74, 71, 70, 74, 77, 77, 75, 75, 78, 75, 76, 73, 75, 75, 79, 77, 76, 71, 75, 74, 69, 71, 76, 72, 72, 70, 72, 73, 71, 72, 71, 73, 72, 73, 74, 74, 72, 75, 74, 74, 77, 75, 73, 72, 71, 74, 77, 75, 75, 75, 78, 78, 74, 76, 78, 76, 70, 72, 80, 74, 74, 71, 70, 72,    71, 74, 71, 72, 71, 74, 69, 76, 75, 75, 76, 73, 76, 73, 77, 73, 72, 72, 77, 77, 71, 74, 74, 73, 78, 75, 73, 70, 74, 72, 73, 73, 75, 75, 74, 76, 73, 74, 75, 75, 72, 73, 73, 72, 74, 78, 76, 73, 74, 75, 70, 75, 71, 72, 78, 75, 73, 73, 71, 75, 77, 72, 69, 73, 74, 72, 70, 75, 70, 72,    72, 74, 73, 74, 76, 75, 80, 72, 75, 73, 74, 74, 73, 75, 75, 71, 73, 75, 74, 74, 72, 74, 74, 74,
, 186, 170, 197, 219, 200, 220, 207, 225, 207, 212, 225, 170, 190, 210, 230, 210, 200, 238, 234, 222, 200, 190, 170, 220, 223, 210, 215, 196, 175, 175, 189, 205, 210, 180, 180, 197, 220, 228, 190, 204, 165, 216, 220, 208, 210, 215, 195, 200, 215, 229, 240, 207, 205, 208, 185, 190, 170, 208, 225, 190, 225, 185, 180, 165, 240, 220, 212, 163, 215, 175, 205, 210, 205, 208, 215, 180, 200, 230, 211, 230, 190, 220, 180, 205, 190, 180, 205, 190, 195]

# %%
df = pd.DataFrame({'Height':l_height,'Weight':l_weight})

# %%
df
# Out:
#       Height  Weight
# 0         74     180
# 1         74     215
# 2         72     210
# 3         72     210
# 4         73     188
# 5         69     176
# 6         69     209
# 7         71     200
# 8         76     231
# 9         71     180
# 10        73     188
# 11        73     180
# 12        74     185
# 13        74     160
# 14        69     180
# 15        70     185
# 16        73     189
# 17        75     185
# 18        78     219
# 19        79     230
# 20        76     205
# 21        74     230
# 22        76     195
# 23        72     180
# 24        71     192
# 25        75     225
# 26        77     203
# 27        74     195
# 28        73     182
# 29        74     188
# ...      ...     ...
# 985       73     190
# 986       75     225
# 987       73     185
# 988       67     180
# 989       67     165
# 990       76     240
# 991       74     220
# 992       73     212
# 993       70     163
# 994       75     215
# 995       70     175
# ...

# %%
df.shape
# Out:
# (1015, 2)

# %%
df.tail()
# Out:
#       Height  Weight
# 1010      73     190
# 1011      74     180
# 1012      75     205
# 1013      75     190
# 1014      73     195

# %%
df.describe()
# Out:
#             Height       Weight
# count  1015.000000  1015.000000
# mean     73.689655   201.348768
# std       2.313932    20.823115
# min      67.000000   150.000000
# 25%      72.000000   186.000000
# 50%      74.000000   200.000000
# 75%      75.000000   215.000000
# max      83.000000   290.000000

# %%
employees = pd.read_excel('employees.xls')

# %%
type(employees)
# Out:
# pandas.core.frame.DataFrame

# %%
employees.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
employees.shape
# Out:
# (107, 11)

# %%
employees('FIRST_NAME')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-084656d55d37> in <module>
# ----> 1 employees('FIRST_NAME')
#
# TypeError: 'DataFrame' object is not callable

# %%
type(employees['FIRST_NAME'])
# Out:
# pandas.core.series.Series

# %%
employees.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
employees[employess['DEPARTMENT_ID'].isna()]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL        PHONE_NUMBER  \
# 78          178  Kimberely     Grant  KGRANT  011.44.1644.429263
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 78            NaN

# %%
# sap tang theo SALARY
employees.sort_values(by='SALARY')
# Out:
#      EMPLOYEE_ID FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 32           132         TJ        Olson   TJOLSON        650.124.8234
# 36           136      Hazel   Philtanker  HPHILTAN        650.127.1634
# 28           128     Steven       Markle   SMARKLE        650.124.1434
# 35           135         Ki          Gee      KGEE        650.127.1734
# 27           127      James       Landry   JLANDRY        650.124.1334
# 19           119      Karen   Colmenares  KCOLMENA        515.127.4566
# 31           131      James       Marlow   JAMRLOW        650.124.7234
# 40           140     Joshua        Patel    JPATEL        650.121.1834
# 91           191    Randall      Perkins  RPERKINS        650.505.4876
# 82           182     Martha     Sullivan  MSULLIVA        650.507.9878
# 44           144      Peter       Vargas   PVARGAS        650.121.2004
# 43           143    Randall        Matos    RMATOS        650.121.2874
# ...

# %%
# sap giam theo SALARY
employees.sort_values(by='SALARY', ascending=False)
# Out:
#      EMPLOYEE_ID FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100     Steven         King     SKING        515.123.4567
# 2            102        Lex      De Haan   LDEHAAN        515.123.4569
# 1            101      Neena      Kochhar  NKOCHHAR        515.123.4568
# 45           145       John      Russell   JRUSSEL  011.44.1344.429268
# 46           146      Karen     Partners  KPARTNER  011.44.1344.467268
# 101          201    Michael    Hartstein  MHARTSTE        515.123.5555
# 8            108      Nancy    Greenberg  NGREENBE        515.124.4569
# 105          205    Shelley      Higgins  SHIGGINS        515.123.8080
# 47           147    Alberto    Errazuriz  AERRAZUR  011.44.1344.429278
# 68           168       Lisa         Ozer     LOZER  011.44.1343.929268
# 48           148     Gerald    Cambrault  GCAMBRAU  011.44.1344.619268
# 74           174      Ellen         Abel     EABEL  011.44.1644.429267
# ...

# %%
# sap tang theo DEPARTMENT_ID va SALARY
employees.sort_values(by=['DEPARTMENT_ID','SALARY'])
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 100          200     Jennifer       Whalen   JWHALEN        515.123.4444
# 102          202          Pat          Fay      PFAY        603.123.6666
# 101          201      Michael    Hartstein  MHARTSTE        515.123.5555
# 19           119        Karen   Colmenares  KCOLMENA        515.127.4566
# 18           118          Guy       Himuro   GHIMURO        515.127.4565
# 17           117        Sigal       Tobias   STOBIAS        515.127.4564
# 16           116       Shelli        Baida    SBAIDA        515.127.4563
# 15           115    Alexander         Khoo     AKHOO        515.127.4562
# 14           114          Den     Raphaely  DRAPHEAL        515.127.4561
# 103          203        Susan       Mavris   SMAVRIS        515.123.7777
# 32           132           TJ        Olson   TJOLSON        650.124.8234
# 28           128       Steven       Markle   SMARKLE        650.124.1434
# ...

# %%
# sap xep theo DEPARTMENT_ID va SALARY va chon giu lai cot
employees.sort_values(by=['DEPARTMENT_ID','SALARY'])[['EMPLOYEE_ID','FIRST_NAME','DEPARTMENT_ID','SALARY']]
# Out:
#      EMPLOYEE_ID   FIRST_NAME  DEPARTMENT_ID  SALARY
# 100          200     Jennifer           10.0    4400
# 102          202          Pat           20.0    6000
# 101          201      Michael           20.0   13000
# 19           119        Karen           30.0    2500
# 18           118          Guy           30.0    2600
# 17           117        Sigal           30.0    2800
# 16           116       Shelli           30.0    2900
# 15           115    Alexander           30.0    3100
# 14           114          Den           30.0   11000
# 103          203        Susan           40.0    6500
# 32           132           TJ           50.0    2100
# 28           128       Steven           50.0    2200
# 36           136        Hazel           50.0    2200
# 27           127        James           50.0    2400
# 35           135           Ki           50.0    2400
# 31           131        James           50.0    2500
# 40           140       Joshua           50.0    2500
# ...

# %%
emp_sort = employees[['EMPLOYEE_ID','FIRST_NAME','DEPARTMENT_ID','SALARY']]

# %%
emp_sort
# Out:
#      EMPLOYEE_ID   FIRST_NAME  DEPARTMENT_ID  SALARY
# 0            100       Steven           90.0   24000
# 1            101        Neena           90.0   17000
# 2            102          Lex           90.0   17000
# 3            103    Alexander           60.0    9000
# 4            104        Bruce           60.0    6000
# 5            105        David           60.0    4800
# 6            106        Valli           60.0    4800
# 7            107        Diana           60.0    4200
# 8            108        Nancy          100.0   12008
# 9            109       Daniel          100.0    9000
# 10           110         John          100.0    8200
# 11           111       Ismael          100.0    7700
# 12           112  Jose Manuel          100.0    7800
# 13           113         Luis          100.0    6900
# 14           114          Den           30.0   11000
# 15           115    Alexander           30.0    3100
# 16           116       Shelli           30.0    2900
# ...

# %%
emp_sort.sort_values(by=['DEPARTMENT_ID','SALARY'])
# Out:
#      EMPLOYEE_ID   FIRST_NAME  DEPARTMENT_ID  SALARY
# 100          200     Jennifer           10.0    4400
# 102          202          Pat           20.0    6000
# 101          201      Michael           20.0   13000
# 19           119        Karen           30.0    2500
# 18           118          Guy           30.0    2600
# 17           117        Sigal           30.0    2800
# 16           116       Shelli           30.0    2900
# 15           115    Alexander           30.0    3100
# 14           114          Den           30.0   11000
# 103          203        Susan           40.0    6500
# 32           132           TJ           50.0    2100
# 28           128       Steven           50.0    2200
# 36           136        Hazel           50.0    2200
# 27           127        James           50.0    2400
# 35           135           Ki           50.0    2400
# 31           131        James           50.0    2500
# 40           140       Joshua           50.0    2500
# ...

# %%
emp_sort.sort_values(by=['DEPARTMENT_ID','SALARY'],ascending=[True,False])
# Out:
#      EMPLOYEE_ID   FIRST_NAME  DEPARTMENT_ID  SALARY
# 100          200     Jennifer           10.0    4400
# 101          201      Michael           20.0   13000
# 102          202          Pat           20.0    6000
# 14           114          Den           30.0   11000
# 15           115    Alexander           30.0    3100
# 16           116       Shelli           30.0    2900
# 17           117        Sigal           30.0    2800
# 18           118          Guy           30.0    2600
# 19           119        Karen           30.0    2500
# 103          203        Susan           40.0    6500
# 21           121         Adam           50.0    8200
# 20           120      Matthew           50.0    8000
# 22           122        Payam           50.0    7900
# 23           123       Shanta           50.0    6500
# 24           124        Kevin           50.0    5800
# 84           184      Nandita           50.0    4200
# 85           185       Alexis           50.0    4100
# ...

# %%
employees.bar
