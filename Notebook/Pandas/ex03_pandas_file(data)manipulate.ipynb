# %%
import numpy as np
import pandas as pd

# %%
df_cn = pd.read_csv('sinh_vien_CN.csv')
df_to = pd.read_csv('sinh_vien_TO.csv')
df_vl = pd.read_csv('sinh_vien_VL.csv')

# %%
df_cn.shape
# Out:
# (500, 10)

# %%
df_cn.head()
# Out:
#     masv              ho    ten  gioitinh             ngaysinh  \
# 0  C0001     Khương Thảo   Loan     False  1999-01-04 00:00:00
# 1  C0002       Đặng Bạch   Ngọc      True  1999-11-11 00:00:00
# 2  C0003   Phạm Văn Minh  Thiện      True  1999-11-23 00:00:00
# 3  C0004  Đinh Thị Thanh   Dung     False  1999-01-19 00:00:00
# 4  C0005       Trần Mạnh  Thiện      True  1999-08-19 00:00:00
#
#                 email     didong          cmnd  hocbong makh
# 0    ktloan@gmail.com  987314518  586900775484  2000000   CN
# 1    dbngoc@gmail.com  987587327  274387352269        0   CN
# 2  pvmthien@gmail.com  987858734  835772714136        0   CN
# 3   dttdung@gmail.com  987508413  373064334392  1000000   CN
# 4   tmthien@gmail.com  987579776  233384596844  1000000   CN

# %%
df = pd.concat([df_cn,df_to,df_vl])

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.head(10)
# Out:
#     masv               ho    ten  gioitinh             ngaysinh  \
# 0  C0001      Khương Thảo   Loan     False  1999-01-04 00:00:00
# 1  C0002        Đặng Bạch   Ngọc      True  1999-11-11 00:00:00
# 2  C0003    Phạm Văn Minh  Thiện      True  1999-11-23 00:00:00
# 3  C0004   Đinh Thị Thanh   Dung     False  1999-01-19 00:00:00
# 4  C0005        Trần Mạnh  Thiện      True  1999-08-19 00:00:00
# 5  C0006    Trần Văn Minh   Hiệu      True  1999-12-12 00:00:00
# 6  C0007           Lê Thị    Mai     False  1999-09-13 00:00:00
# 7  C0008        Bạch Vĩnh   Tuấn      True  1999-06-08 00:00:00
# 8  C0009   Thái Thị Thanh  Nhung     False  1999-07-18 00:00:00
# 9  C0010  Khương Văn Minh  Trọng      True  1999-10-01 00:00:00
#
#                 email     didong          cmnd  hocbong makh
# 0    ktloan@gmail.com  987314518  586900775484  2000000   CN
# 1    dbngoc@gmail.com  987587327  274387352269        0   CN
# 2  pvmthien@gmail.com  987858734  835772714136        0   CN
# ...

# %%
df = df.reset_index()

# %%
df(tail)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5eb15d2a9896> in <module>
# ----> 1 df(tail)
#
# NameError: name 'tail' is not defined

# %%
df_kq=pd.read_csv('ket_qua.csv')

# %%
df_dtb = df_kq.groupby('masv', as_index=False).diem.mean()
type(df_dtb)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ = pd.merge(df,df_dtb, on='masv',how='inner')

# %%
df_.drop(columns=['index'],inplace=True)

# %%
df_
# Out:
#       masv                ho     ten  gioitinh             ngaysinh  \
# 0    C0001       Khương Thảo    Loan     False  1999-01-04 00:00:00
# 1    C0002         Đặng Bạch    Ngọc      True  1999-11-11 00:00:00
# 2    C0003     Phạm Văn Minh   Thiện      True  1999-11-23 00:00:00
# 3    C0004    Đinh Thị Thanh    Dung     False  1999-01-19 00:00:00
# 4    C0005         Trần Mạnh   Thiện      True  1999-08-19 00:00:00
# 5    C0006     Trần Văn Minh    Hiệu      True  1999-12-12 00:00:00
# 6    C0007            Lê Thị     Mai     False  1999-09-13 00:00:00
# 7    C0008         Bạch Vĩnh    Tuấn      True  1999-06-08 00:00:00
# 8    C0009    Thái Thị Thanh   Nhung     False  1999-07-18 00:00:00
# 9    C0010   Khương Văn Minh   Trọng      True  1999-10-01 00:00:00
# 10   C0011        Hoàng Thảo    Thúy     False  1999-12-07 00:00:00
# 11   C0012           Mã Vĩnh   Thiệu      True  1999-10-09 00:00:00
# 12   C0013       Nguyễn Minh     Thu     False  1999-07-18 00:00:00
# ...

# %%
df_['diem'].describe()
# Out:
# count    1000.000000
# mean        7.214300
# std         0.553463
# min         5.150000
# 25%         6.850000
# 50%         7.250000
# 75%         7.600000
# max         8.750000
# Name: diem, dtype: float64

# %%
# cho biet sinh vien co diem nho nhat
df_[df_['diem']==df_['diem'].min()]
# Out:
#       masv        ho   ten  gioitinh             ngaysinh             email  \
# 832  V0833  Trần Phú  Minh     False  1999-05-24 00:00:00  tpminh@gmail.com
#
#         didong          cmnd  hocbong makh  diem
# 832  168861731  190672558617  2000000   VL  5.15

# %%
# cho biet cac nam sinh vien khong co hoc bong
df_[(df_['gioitinh']) & (df_['hocbong']==0) & (df_['makh']=='VL')]
# Out:
#       masv               ho    ten  gioitinh             ngaysinh  \
# 605  V0606           Mã Nam  Thiệu      True  1999-06-15 00:00:00
# 617  V0618       Vương Mạnh    Huy      True  1999-11-13 00:00:00
# 627  V0628      Khương Vĩnh   Dũng      True  1999-06-27 00:00:00
# 634  V0635          Văn Văn    Huy      True  1999-12-04 00:00:00
# 645  V0646         Thái Nam   Sinh      True  1999-01-05 00:00:00
# 649  V0650        Phạm Mạnh    Lộc      True  1999-11-05 00:00:00
# 652  V0653       Hoàng Mạnh     Vỹ      True  1999-09-14 00:00:00
# 665  V0666      Mã Văn Minh  Thiện      True  1999-08-30 00:00:00
# 673  V0674         Bạch Nam  Thiệu      True  1999-08-14 00:00:00
# 678  V0679        Phạm Bạch   Minh      True  1999-04-26 00:00:00
# 685  V0686        Phạm Vĩnh  Phong      True  1999-08-05 00:00:00
# 687  V0688     Lâm Văn Minh  Thiệu      True  1999-11-10 00:00:00
# 692  V0693          Lê Bạch  Thanh      True  1999-06-27 00:00:00
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
# masv        1000 non-null object
# ho          1000 non-null object
# ten         1000 non-null object
# gioitinh    1000 non-null bool
# ngaysinh    1000 non-null object
# email       1000 non-null object
# didong      1000 non-null int64
# cmnd        1000 non-null int64
# hocbong     1000 non-null int64
# makh        1000 non-null object
# diem        1000 non-null float64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 86.9+ KB
