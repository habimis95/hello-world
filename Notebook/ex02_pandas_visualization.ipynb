# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Diemthi_thpt_quocgia_2016.csv')

# %%
df
# Out:
#        SOBAODANH              HO_TEN   NGAY_SINH  \
# 0       18000001       DƯƠNG VIỆT AN  12/03/1998
# 1       18000002           ĐỖ VĂN AN   9/12/1998
# 2       18000003          ĐỖ XUÂN AN  12/08/1997
# 3       18000004        ĐẶNG PHÚC AN  19/03/1998
# 4       18000005         ĐẶNG VĂN AN  25/10/1998
# 5       18000006           HÀ THỊ AN  22/06/1998
# 6       18000007           HÀ THỊ AN  23/04/1997
# 7       18000008          HỨA VĂN AN  25/05/1998
# 8       18000009        HOÀNG VĂN AN  22/02/1998
# 9       18000010           LA VĂN AN  19/08/1998
# 10      18000011          LÊ MẠNH AN   9/01/1998
# 11      18000012           LÝ THỊ AN  27/05/1998
# 12      18000013         MẠC CÔNG AN  28/08/1998
# 13      18000014          NGÔ THỊ AN  10/03/1998
# 14      18000015      NGUYỄN BÌNH AN   8/05/1998
# 15      18000016       NGUYỄN ĐỨC AN  25/10/1998
# 16      18000017      NGUYỄN NGỌC AN  15/07/1998
# 17      18000018       NGUYỄN THỊ AN  16/03/1998
# ...

# %%
df.shape
# Out:
# (34826, 6)

# %%
df.iloc[0]['DIEM_THI']
# Out:
# 'Toán:   2.00   Ngữ văn:   5.50   Lịch sử:   3.00   Địa lí:   5.00'

# %%
df.iloc[0]['DIEM_THI'].split('  ').replace(':',0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c53dad0a8e52> in <module>
# ----> 1 df.iloc[0]['DIEM_THI'].split('  ').replace(':',0)
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
df = pd.read_excel('employees.xls')

# %%
df.shape
# Out:
# (107, 11)

# %%
df.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
df.plot.bar()

# %%
df.groupby('DEPARTMENT_ID')['SALARY'].sum().plot.bar()

# %%
df_dep = df.groupby('DEPARTMENT_ID', as_index=True)['SALARY'].sum()

# %%
df_dep.plot()

# %%
df['SALARY'].plot.box(grid=True)

# %%
df['SALARY'].describe()
# Out:
# count      107.000000
# mean      6461.831776
# std       3909.579731
# min       2100.000000
# 25%       3100.000000
# 50%       6200.000000
# 75%       8900.000000
# max      24000.000000
# Name: SALARY, dtype: float64

# %%
df['SALARY'].plot()

# %%
df_1=df[['EMPLOYEE_ID','FIRST_NAME','LAST_NAME']]

# %%
df.iloc[0:2]
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0

# %%
df[df['SALARY']>10000]
# Out:
#      EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100     Steven       King     SKING        515.123.4567
# 1            101      Neena    Kochhar  NKOCHHAR        515.123.4568
# 2            102        Lex    De Haan   LDEHAAN        515.123.4569
# 8            108      Nancy  Greenberg  NGREENBE        515.124.4569
# 14           114        Den   Raphaely  DRAPHEAL        515.127.4561
# 45           145       John    Russell   JRUSSEL  011.44.1344.429268
# 46           146      Karen   Partners  KPARTNER  011.44.1344.467268
# 47           147    Alberto  Errazuriz  AERRAZUR  011.44.1344.429278
# 48           148     Gerald  Cambrault  GCAMBRAU  011.44.1344.619268
# 49           149      Eleni    Zlotkey  EZLOTKEY  011.44.1344.429018
# 62           162      Clara    Vishney  CVISHNEY  011.44.1346.129268
# 68           168       Lisa       Ozer     LOZER  011.44.1343.929268
# 74           174      Ellen       Abel     EABEL  011.44.1644.429267
# ...

# %%
df_2=df[df['SALARY']>10000][['EMPLOYEE_ID','FIRST_NAME','LAST_NAME','SALARY']]

# %%
df_2.sort_values(by='SALARY',ascending=False)
# Out:
#      EMPLOYEE_ID FIRST_NAME  LAST_NAME  SALARY
# 0            100     Steven       King   24000
# 1            101      Neena    Kochhar   17000
# 2            102        Lex    De Haan   17000
# 45           145       John    Russell   14000
# 46           146      Karen   Partners   13500
# 101          201    Michael  Hartstein   13000
# 8            108      Nancy  Greenberg   12008
# 105          205    Shelley    Higgins   12008
# 47           147    Alberto  Errazuriz   12000
# 68           168       Lisa       Ozer   11500
# 14           114        Den   Raphaely   11000
# 48           148     Gerald  Cambrault   11000
# 74           174      Ellen       Abel   11000
# 49           149      Eleni    Zlotkey   10500
# 62           162      Clara    Vishney   10500

# %%
df_2.sort_values(by='SALARY',ascending=False).reset_index(drop=True)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME  SALARY
# 0           100     Steven       King   24000
# 1           101      Neena    Kochhar   17000
# 2           102        Lex    De Haan   17000
# 3           145       John    Russell   14000
# 4           146      Karen   Partners   13500
# 5           201    Michael  Hartstein   13000
# 6           108      Nancy  Greenberg   12008
# 7           205    Shelley    Higgins   12008
# 8           147    Alberto  Errazuriz   12000
# 9           168       Lisa       Ozer   11500
# 10          114        Den   Raphaely   11000
# 11          148     Gerald  Cambrault   11000
# 12          174      Ellen       Abel   11000
# 13          149      Eleni    Zlotkey   10500
# 14          162      Clara    Vishney   10500

# %%
df.groupby('DEPARTMENT_ID').mean()
# Out:
#                EMPLOYEE_ID        SALARY  COMMISSION_PCT  MANAGER_ID
# DEPARTMENT_ID
# 10.0            200.000000   4400.000000             NaN  101.000000
# 20.0            201.500000   9500.000000             NaN  150.500000
# 30.0            116.500000   4150.000000             NaN  111.666667
# 40.0            203.000000   6500.000000             NaN  101.000000
# 50.0            157.555556   3475.555556             NaN  119.555556
# 60.0            105.000000   5760.000000             NaN  102.800000
# 70.0            204.000000  10000.000000             NaN  101.000000
# 80.0            161.529412   8955.882353           0.225  140.029412
# 90.0            101.000000  19333.333333             NaN  100.000000
# 100.0           110.500000   8601.333333             NaN  106.833333
# 110.0           205.500000  10154.000000             NaN  153.000000

# %%
df.groupby('DEPARTMENT_ID')['SALARY'].mean()
# Out:
# DEPARTMENT_ID
# 10.0      4400.000000
# 20.0      9500.000000
# 30.0      4150.000000
# 40.0      6500.000000
# 50.0      3475.555556
# 60.0      5760.000000
# 70.0     10000.000000
# 80.0      8955.882353
# 90.0     19333.333333
# 100.0     8601.333333
# 110.0    10154.000000
# Name: SALARY, dtype: float64

# %%
df.groupby(['DEPARTMENT_ID','JOB_ID'],as_index=False).SALARY.mean()
# Out:
#     DEPARTMENT_ID      JOB_ID        SALARY
# 0            10.0     AD_ASST   4400.000000
# 1            20.0      MK_MAN  13000.000000
# 2            20.0      MK_REP   6000.000000
# 3            30.0    PU_CLERK   2780.000000
# 4            30.0      PU_MAN  11000.000000
# 5            40.0      HR_REP   6500.000000
# 6            50.0    SH_CLERK   3215.000000
# 7            50.0    ST_CLERK   2785.000000
# 8            50.0      ST_MAN   7280.000000
# 9            60.0     IT_PROG   5760.000000
# 10           70.0      PR_REP  10000.000000
# 11           80.0      SA_MAN  12200.000000
# 12           80.0      SA_REP   8396.551724
# 13           90.0     AD_PRES  24000.000000
# 14           90.0       AD_VP  17000.000000
# 15          100.0  FI_ACCOUNT   7920.000000
# 16          100.0      FI_MGR  12008.000000
# 17          110.0  AC_ACCOUNT   8300.000000
# 18          110.0      AC_MGR  12008.000000

# %%
df.groupby('DEPARTMENT_ID')['SALARY'].agg(['sum','count','min','max','mean'])
# Out:
#                   sum  count    min    max          mean
# DEPARTMENT_ID
# 10.0             4400      1   4400   4400   4400.000000
# 20.0            19000      2   6000  13000   9500.000000
# 30.0            24900      6   2500  11000   4150.000000
# 40.0             6500      1   6500   6500   6500.000000
# 50.0           156400     45   2100   8200   3475.555556
# 60.0            28800      5   4200   9000   5760.000000
# 70.0            10000      1  10000  10000  10000.000000
# 80.0           304500     34   6100  14000   8955.882353
# 90.0            58000      3  17000  24000  19333.333333
# 100.0           51608      6   6900  12008   8601.333333
# 110.0           20308      2   8300  12008  10154.000000
